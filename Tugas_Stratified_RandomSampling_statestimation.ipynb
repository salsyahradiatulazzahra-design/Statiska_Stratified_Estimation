# %%
import pandas as pd
data = pd.read_csv('MovieData-2018-2020.csv')
data
# Out:
#                        name rating      genre  year  \
# 0             A Quiet Place  PG-13      Drama  2018
# 1    Avengers: Infinity War  PG-13     Action  2018
# 2                Deadpool 2      R     Action  2018
# 3         Bohemian Rhapsody  PG-13  Biography  2018
# 4             Black Panther  PG-13     Action  2018
# ..                      ...    ...        ...   ...
# 269        Love by Drowning      R      Drama  2020
# 270           The Robinsons    NaN     Action  2020
# 271            More to Life    NaN      Drama  2020
# 272           Saving Mbango    NaN      Drama  2020
# 273            It's Just Us    NaN      Drama  2020
#
#                               released  score     votes           director  \
# 0        April 6, 2018 (United States)    7.5  456000.0     John Krasinski
# 1       April 27, 2018 (United States)    8.4  897000.0      Anthony Russo
# 2         May 18, 2018 (United States)    7.7  505000.0       David Leitch
# 3     November 2, 2018 (United States)    7.9  476000.0       Bryan Singer
# 4    February 16, 2018 (United States)    7.3  661000.0       Ryan Coogler
# ..                                 ...    ...       ...                ...
# 269   November 6, 2020 (United States)    NaN       NaN  Justin Kreinbrink
# 270  November 10, 2020 (United States)    NaN       NaN          Directors
# 271   October 23, 2020 (United States)    3.1      18.0      Joseph Ebanks
# 272          April 27, 2020 (Cameroon)    5.7      29.0       Nkanya Nkwai
# 273    October 1, 2020 (United States)    NaN       NaN      James Randall
#
#                    writer               star         country       budget  \
# 0             Bryan Woods        Emily Blunt   United States   17000000.0
# 1      Christopher Markus  Robert Downey Jr.   United States  321000000.0
# 2             Rhett Reese      Ryan Reynolds          Canada  110000000.0
# 3        Anthony McCarten         Rami Malek  United Kingdom   52000000.0
# 4            Ryan Coogler   Chadwick Boseman   United States  200000000.0
# ..                    ...                ...             ...          ...
# 269         C.E. Poverman       Nicky Whelan   United States    1000000.0
# 270  Aleks Alifirenko Jr.     Billy Hartmann   United States      10000.0
# 271         Joseph Ebanks       Shannon Bond   United States       7000.0
# 272          Lynno Lovert       Onyama Laura   United States      58750.0
# 273         James Randall      Christina Roz   United States      15000.0
#
#             gross                company  runtime
# 0    3.503204e+08     Paramount Pictures     90.0
# 1    2.048360e+09         Marvel Studios    149.0
# 2    7.864705e+08  Twentieth Century Fox    119.0
# 3    9.119026e+08  Twentieth Century Fox    134.0
# 4    1.347598e+09         Marvel Studios    134.0
# ..            ...                    ...      ...
# 269           NaN         Dow Jazz Films    121.0
# 270           NaN                    NaN     90.0
# 271           NaN                    NaN     90.0
# 272           NaN       Embi Productions      NaN
# 273           NaN                    NaN    120.0
#
# [274 rows x 15 columns]

# %%
# Stratifed data by genre
from sklearn.model_selection import train_test_split

_, stratified_sample = train_test_split(
    data,
    test_size=0.3,
    stratify=data['genre'],
    random_state=4
)

stratified_sample
# Out:
#                                       name     rating      genre  year  \
# 16                            The Predator          R     Action  2018
# 72                               First Man      PG-13  Biography  2018
# 27                          Instant Family      PG-13     Comedy  2018
# 157              Spider-Man: Far from Home      PG-13     Action  2019
# 195                        Five Feet Apart      PG-13      Drama  2019
# ..                                     ...        ...        ...   ...
# 256                                 Mine 9  Not Rated      Drama  2019
# 154  Fast & Furious Presents: Hobbs & Shaw      PG-13     Action  2019
# 224                                  Shaft          R     Action  2019
# 76                                Replicas      PG-13      Drama  2018
# 146                Fighting with My Family      PG-13  Biography  2019
#
#                                released  score     votes            director  \
# 16   September 14, 2018 (United States)    5.3  120000.0         Shane Black
# 72     October 12, 2018 (United States)    7.3  176000.0     Damien Chazelle
# 27    November 16, 2018 (United States)    7.3   97000.0         Sean Anders
# 157        July 2, 2019 (United States)    7.5  359000.0           Jon Watts
# 195      March 15, 2019 (United States)    7.2   51000.0      Justin Baldoni
# ..                                  ...    ...       ...                 ...
# 256               May 19, 2020 (Poland)    6.4    4400.0       Eddie Mensore
# 154      August 2, 2019 (United States)    6.4  184000.0        David Leitch
# 224       June 14, 2019 (United States)    6.4   48000.0           Tim Story
# 76     January 11, 2019 (United States)    5.5   34000.0  Jeffrey Nachmanoff
# 146   February 22, 2019 (United States)    7.1   71000.0    Stephen Merchant
#
#                writer                 star         country       budget  \
# 16        Fred Dekker        Boyd Holbrook   United States   88000000.0
# 72        Josh Singer         Ryan Gosling   United States   59000000.0
# 27        Sean Anders        Mark Wahlberg   United States   48000000.0
# 157     Chris McKenna          Tom Holland   United States  160000000.0
# 195    Mikki Daughtry  Haley Lu Richardson   United States    7000000.0
# ..                ...                  ...             ...          ...
# 256     Eddie Mensore        Terry Serpico   United States     350000.0
# 154      Chris Morgan       Dwayne Johnson   United States  200000000.0
# 224    Ernest Tidyman    Samuel L. Jackson   United States   35000000.0
# 76      Chad St. John         Keanu Reeves  United Kingdom   30000000.0
# 146  Stephen Merchant       Dwayne Johnson  United Kingdom   11000000.0
#
#             gross                          company  runtime
# 16   1.605421e+08            Twentieth Century Fox    107.0
# 72   1.057132e+08               Universal Pictures    141.0
# 27   1.205562e+08  Closest to the Hole Productions    118.0
# 157  1.131928e+09                Columbia Pictures    129.0
# 195  9.152780e+07                        CBS Films    116.0
# ..            ...                              ...      ...
# 256  2.264210e+05                   Emphatic Films     83.0
# 154  7.590569e+08         Chris Morgan Productions    137.0
# 224  2.136022e+07              Davis Entertainment    111.0
# 76   9.330075e+06                    Company Films    107.0
# 146  4.081192e+07        Metro-Goldwyn-Mayer (MGM)    108.0
#
# [109 rows x 15 columns]

# %%
# Melihat jumlah data setiap genre
data["genre"].value_counts()
# Out:
# genre
# Action       88
# Comedy       45
# Drama        38
# Biography    29
# Animation    23
# Adventure    19
# Horror       15
# Crime        12
# Fantasy       3
# Name: count, dtype: int64

# %%
# Mengambil 30 data teratas
sample = stratified_sample.head(30)
sample
# Out:
#                                   name rating      genre  year  \
# 160                     It Chapter Two      R      Drama  2019
# 46    United States   23000000.0  3.493401e+07
# 1     United States  321000000.0  2.048360e+09
# 183   United States  200000000.0  1.073395e+09
# 5     United States   10000000.0  8.023966e+07
# 223   United States   21000000.0  9.501704e+07
# 104          Canada   10000000.0  6.412349e+06
# 195   United States    7000000.0  9.152780e+07
# 176   United States   10000000.0  1.020981e+07
# 209   United States    9000000.0  1.231337e+08
#
#                                   company  runtime
# 160                       New Line Cinema    169.0
# 222                  Walt Disney Pictures    112.0
# 144                     Columbia Pictures    161.0
# 152                             Lionsgate    130.0
# 181                    Paramount Pictures    121.0
# 229                       New Line Cinema    118.0
# 163                 Chernin Entertainment    152.0
# 250                        Orion Pictures     92.0
# 201             Metro-Goldwyn-Mayer (MGM)     86.0
# 125                        Huayi Brothers    103.0
# 155                  Walt Disney Pictures    123.0
# 127                           Screen Gems     86.0
# 174                     Paramount Players    102.0
# 171            Carnival Film & Television    122.0
# 265                  20th Century Studios    100.0
# 177                  Walt Disney Pictures    118.0
# 105                                 2DUX²    104.0
# 25                     Universal Pictures    114.0
# 185                  Summit Entertainment    125.0
# 208                    Universal Pictures     86.0
# 130                             CBS Films     99.0
# 46                      Fox 2000 Pictures    133.0
# 1                          Marvel Studios    149.0
# 183               Pixar Animation Studios    100.0
# 5                          PalmStar Media    127.0
# 223             Metro-Goldwyn-Mayer (MGM)     93.0
# 104  Emmett/Furla/Oasis Films (EFO Films)    112.0
# 195                             CBS Films    116.0
# 176                          Astute Films    133.0
# 209                       New Line Cinema     93.0

# %%
# Menghitung rata rata budget dan standar deviasi
x_bar = sample['budget'].mean() / 1000000
s = sample['budget'].std() / 1000000

print("Rata-rata Budget : {:.2f} juta".format(x_bar))
print("Standar Deviasi : {:.2f} juta".format(s))
# Out:
# Rata-rata Budget : 70.73 juta
# Standar Deviasi : 80.68 juta

# %% [markdown]
# MENGHITUNG ESTIMASI

# %%
import scipy.stats as stats
import math

# Specify sample mean (x_bar), sample standard deviation (s), sample size (n) and confidence level
x_bar = 70.73
s = 80.68
n = 30
confidence_level = 0.95

# Calculate alpha, degrees of freedom (df), the critical t-value, and the margin of error
alpha = (1-confidence_level)
df = n - 1
standard_error = s/math.sqrt(n)
critical_t = stats.t.ppf(1-alpha/2, df)
margin_of_error = critical_t * standard_error

# Calculate the lower and upper bound of the confidence interval
lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

# Print the results
print("Critical t-value: {:.3f}".format(critical_t))
print("Margin of Error: {:.3f}".format(margin_of_error))
print("Confidence Interval: [{:.3f},{:.3f}]".format(lower_bound,upper_bound))
print("The {:.1%} confidence interval for the population mean is:".format(confidence_level))
print("between {:.3f} and {:.3f}".format(lower_bound,upper_bound))
# Out:
# Critical t-value: 2.045
# Margin of Error: 30.126
# Confidence Interval: [40.604,100.856]
# The 95.0% confidence interval for the population mean is:
# between 40.604 and 100.856
